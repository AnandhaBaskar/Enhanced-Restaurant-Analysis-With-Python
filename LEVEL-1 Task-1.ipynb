# %% [markdown]
# # Import the necessary libraries for Data Analysis and visualization

# %%
import pandas as pd

# %% [markdown]
# # Loading the Restaurant dataset into a DataFrame

# %%
df=pd.read_csv('dataset.csv',encoding='ISO-8859-1')
df.head()
# Out:
#    ï»¿Restaurant ID         Restaurant Name  Country Code              City  \
# 0           6317637        Le Petit Souffle           162       Makati City
# 1           6304287        Izakaya Kikufuji           162       Makati City
# 2           6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                    Ooma           162  Mandaluyong City
# 4           6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# ...

# %% [markdown]
# # LEVEL 1-Task 1: Data Exploration and Preprocessing

# %% [markdown]
# # LEVEL 1-Task 1 (i):Explore the dataset and identify the number of rows and columns.

# %%
rows,columns=df.shape
print("\nNumber of rows:",rows)
print("Number of columns:",columns)
# Out:
# Number of rows: 9551
# Number of columns: 21

# %% [markdown]
# # LEVEL 1-Task 1(ii):Check for missing values in each column and handle them accordingly.

# %%
missing_values=df.isnull().sum()
print("Number of missing values in each column:")
print(missing_values)
#df.drop_duplicates(inplace=True)
#df['Cuisines'].fillna('Not Specified',inplace=True)
# Out:
# Number of missing values in each column:
# ï»¿Restaurant ID        0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# # LEVEL1-Task1(iii):Perform data type conversion if necessary.Analyze the distribution of the target variable("Aggregate rating")and identify any classimbalances.

# %%
df['Votes']=pd.to_numeric(df['Votes'],errors='coerce')
ratingdistribution=df['Aggregate rating'].value_counts()
print("Distribution of Aggregate Ratings:")
print(ratingdistribution)
classimbalance=df['Aggregate rating'].value_counts(normalize=True)
print("\nClass Imbalances in Aggregate Ratings:")
print(classimbalance)
# Out:
# Distribution of Aggregate Ratings:
# Aggregate rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: count, dtype: int64
#
# Class Imbalances in Aggregate Ratings:
# Aggregate rating
# 0.0    0.224898
# 3.2    0.054654
# 3.1    0.054340
# 3.4    0.052141
# 3.3    0.050571
# 3.5    0.050257
# 3.0    0.049000
# 3.6    0.047953
# 3.7    0.044707
# 3.8    0.041880
# 2.9    0.039891
# 3.9    0.035075
# 2.8    0.032981
# 4.1    0.028688
# 4.0    0.027850
# 2.7    0.026175
# 4.2    0.023139
# 2.6    0.019998
# 4.3    0.018218
# 4.4    0.015077
# 2.5    0.011517
# ...
